# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
url = 'https://data.virginia.gov/resource/bre9-aqqr.json'
r = requests.get(url, headers = {'User-agent': 'J. Kropko, class example for UVA data science: jkropko@virginia.edu'})
r
# Out:
# <Response [200]>

# %%
data = pd.json_normalize(json.loads(r.text))
data
# Out:
#                  report_date   fips      locality    vdh_health_district  \
# 0    2021-08-11T00:00:00.000  51001      Accomack          Eastern Shore
# 1    2021-08-11T00:00:00.000  51003     Albemarle             Blue Ridge
# 2    2021-08-11T00:00:00.000  51005     Alleghany              Alleghany
# 3    2021-08-11T00:00:00.000  51007        Amelia               Piedmont
# 4    2021-08-11T00:00:00.000  51009       Amherst       Central Virginia
# ..                       ...    ...           ...                    ...
# 995  2021-08-04T00:00:00.000  51135      Nottoway               Piedmont
# 996  2021-08-04T00:00:00.000  51137        Orange   Rappahannock Rapidan
# 997  2021-08-04T00:00:00.000  51139          Page           Lord Fairfax
# 998  2021-08-04T00:00:00.000  51141       Patrick          West Piedmont
# 999  2021-08-04T00:00:00.000  51143  Pittsylvania  Pittsylvania-Danville
#
#     total_cases hospitalizations deaths
# 0          3024              226     47
# 1          6095              265     85
# 2          1423               72     50
# 3          1009               55     36
# 4          3131              144     40
# ..          ...              ...    ...
# 995        2002              105     52
# 996        2307               85     39
# 997        2201              125     61
# 998        1444              121     46
# 999        5809              280     86
#
# [1000 rows x 7 columns]

# %%
data.query("locality == 'Albemarle'")
# Out:
#                  report_date   fips   locality vdh_health_district  \
# 1    2021-08-11T00:00:00.000  51003  Albemarle          Blue Ridge
# 134  2021-08-10T00:00:00.000  51003  Albemarle          Blue Ridge
# 267  2021-08-09T00:00:00.000  51003  Albemarle          Blue Ridge
# 400  2021-08-08T00:00:00.000  51003  Albemarle          Blue Ridge
# 533  2021-08-07T00:00:00.000  51003  Albemarle          Blue Ridge
# 666  2021-08-06T00:00:00.000  51003  Albemarle          Blue Ridge
# 799  2021-08-05T00:00:00.000  51003  Albemarle          Blue Ridge
# 932  2021-08-04T00:00:00.000  51003  Albemarle          Blue Ridge
#
#     total_cases hospitalizations deaths
# 1          6095              265     85
# 134        6079              265     85
# 267        6073              265     85
# 400        6051              265     85
# 533        6043              265     85
# 666        6027              265     85
# 799        6006              264     85
# 932        5996              264     85
