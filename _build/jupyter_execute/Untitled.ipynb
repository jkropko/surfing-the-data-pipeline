# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
url = 'https://data.virginia.gov/resource/bre9-aqqr.json'
r = requests.get(url, headers = {'User-agent': 'J. Kropko, class example for UVA data science: jkropko@virginia.edu'})
r
# Out:
# <Response [200]>

# %%
data = pd.json_normalize(json.loads(r.text))
data
# Out:
#                  report_date   fips      locality    vdh_health_district  \
# 0    2021-12-27T00:00:00.000  51001      Accomack          Eastern Shore
# 1    2021-12-27T00:00:00.000  51003     Albemarle             Blue Ridge
# 2    2021-12-27T00:00:00.000  51005     Alleghany              Alleghany
# 3    2021-12-27T00:00:00.000  51007        Amelia               Piedmont
# 4    2021-12-27T00:00:00.000  51009       Amherst       Central Virginia
# ..                       ...    ...           ...                    ...
# 995  2021-12-20T00:00:00.000  51135      Nottoway               Piedmont
# 996  2021-12-20T00:00:00.000  51137        Orange   Rappahannock Rapidan
# 997  2021-12-20T00:00:00.000  51139          Page           Lord Fairfax
# 998  2021-12-20T00:00:00.000  51141       Patrick          West Piedmont
# 999  2021-12-20T00:00:00.000  51143  Pittsylvania  Pittsylvania-Danville
#
#     total_cases hospitalizations deaths
# 0          4428              339     83
# 1          9305              351    115
# 2          2481               86     86
# 3          1693               77     43
# 4          4794              247     62
# ..          ...              ...    ...
# 995        2719              137     70
# 996        4300              153     68
# 997        3931              197     90
# 998        2437              138     63
# 999        8841              408    134
#
# [1000 rows x 7 columns]

# %%
data.query("locality == 'Albemarle'")
# Out:
#                  report_date   fips   locality vdh_health_district  \
# 1    2021-12-27T00:00:00.000  51003  Albemarle          Blue Ridge
# 134  2021-12-26T00:00:00.000  51003  Albemarle          Blue Ridge
# 267  2021-12-25T00:00:00.000  51003  Albemarle          Blue Ridge
# 400  2021-12-24T00:00:00.000  51003  Albemarle          Blue Ridge
# 533  2021-12-23T00:00:00.000  51003  Albemarle          Blue Ridge
# 666  2021-12-22T00:00:00.000  51003  Albemarle          Blue Ridge
# 799  2021-12-21T00:00:00.000  51003  Albemarle          Blue Ridge
# 932  2021-12-20T00:00:00.000  51003  Albemarle          Blue Ridge
#
#     total_cases hospitalizations deaths
# 1          9305              351    115
# 134        9263              348    115
# 267        9233              348    115
# 400        9162              348    115
# 533        9097              352    114
# 666        9035              348    114
# 799        8995              347    114
# 932        8970              344    114
